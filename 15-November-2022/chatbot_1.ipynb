# %% [markdown]
# Import library: Dua yang terpenting yaitu json (untuk store database) dan tensorflow (salah satu machine learning tools yang paling populer)

# %%
import json
import string
import random
import nltk
nltk.download('omw-1.4')
import numpy as num
from nltk.stem import WordNetLemmatizer # It has the ability to lemmatize.
import tensorflow as tensorF # A multidimensional array of elements is represented by this symbol.
from tensorflow.keras import Sequential # Sequential groups a linear stack of layers into a tf.keras.Model
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")# required package for tokenization
nltk.download("wordnet")# word database
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# Contoh database berisi label (tag), pattern (pertanyaan) dan responses (jawaban dari pertanyaan)

# %%
ourData = {"ourIntents": [

             {"tag": "age",
              "patterns": ["how old are you?"],
              "responses": ["I am 2 years old and my birthday was yesterday"]
             },
              {"tag": "greeting",
              "patterns": [ "Hi", "Hello", "Hey"],
              "responses": ["Hi there", "Hello", "Hi :)"],
             },
              {"tag": "goodbye",
              "patterns": [ "bye", "later"],
              "responses": ["Bye", "take care"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "who are you?"],
              "responses": ["I have no name yet," "You can give me one, and I will appreciate it"]
             }

]}

# %% [markdown]
# Bersihkan data: Lemmatisasi (kata dasar)
# Juga menyiapkan training untuk mesin learning.
# Dalam machine learning ada input (feature misal gambar kucing) dan ada output (label kucing). Dalam kasus ini, inputnya adalah "pattern" outputnya adalah "tag"

# %%
lm = WordNetLemmatizer() #for getting words
# lists
ourClasses = []
newWords = []
documentX = []
documentY = []
# Each intent is tokenized into words and the patterns and their associated tags are added to their respective lists.
for intent in ourData["ourIntents"]:
    for pattern in intent["patterns"]:
        ournewTkns = nltk.word_tokenize(pattern)# tokenize the patterns
        newWords.extend(ournewTkns)# extends the tokens
        documentX.append(pattern)
        documentY.append(intent["tag"])


    if intent["tag"] not in ourClasses:# add unexisting tags to their respective classes
        ourClasses.append(intent["tag"])

newWords = [lm.lemmatize(word.lower()) for word in newWords if word not in string.punctuation] # set words to lowercase if not in punctuation
newWords = sorted(set(newWords))# sorting words
ourClasses = sorted(set(ourClasses))# sorting classes

# %% [markdown]
# Persiapan training data lebih lanjut

# %%
trainingData = [] # training list array
outEmpty = [0] * len(ourClasses)
# bow model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)

    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = num.array(trainingData, dtype=object)# coverting our data into an array afterv shuffling

x = num.array(list(trainingData[:, 0]))# first trainig phase
y = num.array(list(trainingData[:, 1]))# second training phase

# %% [markdown]
# Kita bangun model dari Neural network nya dan kita jalankan trainingnya

# %%
iShape = (len(x[0]),)
oShape = len(y[0])
# parameter definition
ourNewModel = Sequential()
# In the case of a simple stack of layers, a Sequential model is appropriate

# Dense function adds an output layer
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
# The activation function in a neural network is in charge of converting the node's summed weighted input into activation of the node or output for the input in question
ourNewModel.add(Dropout(0.5))
# Dropout is used to enhance visual perception of input neurons
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation = "softmax"))
# below is a callable that returns the value to be used with no arguments
md = tensorF.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
# Below line improves the numerical stability and pushes the computation of the probability distribution into the categorical crossentropy loss function.
ourNewModel.compile(loss='categorical_crossentropy',
              optimizer=md,
              metrics=["accuracy"])
# Output the model in summary
print(ourNewModel.summary())
# Whilst training your Nural Network, you have the option of making the output verbose or simple.
ourNewModel.fit(x, y, epochs=200, verbose=1)
# By epochs, we mean the number of times you repeat a training set.
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               1920
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 10,436
# Trainable params: 10,436
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 1s 530ms/step - loss: 1.2694 - accuracy: 0.6250
# Epoch 2/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3064 - accuracy: 0.3750
# Epoch 3/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2150 - accuracy: 0.7500
# Epoch 4/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0639 - accuracy: 0.8750
# Epoch 5/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.8495 - accuracy: 1.0000
# Epoch 6/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9231 - accuracy: 0.7500
# Epoch 7/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7746 - accuracy: 0.8750
# Epoch 8/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5002 - accuracy: 1.0000
# Epoch 9/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4755 - accuracy: 1.0000
# Epoch 10/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4323 - accuracy: 1.0000
# Epoch 11/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3347 - accuracy: 0.8750
# Epoch 12/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3318 - accuracy: 0.8750
# Epoch 13/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3205 - accuracy: 1.0000
# Epoch 14/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1562 - accuracy: 1.0000
# Epoch 15/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1290 - accuracy: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0536 - accuracy: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0991 - accuracy: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0648 - accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 11ms/step - loss: 8.7114e-04 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 7ms/step - loss: 8.9344e-04 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0879e-04 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 7ms/step - loss: 7.6351e-04 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.2237e-06 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.5338e-04 - accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0095e-04 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.5144e-04 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 13ms/step - loss: 2.2172e-05 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.4374e-05 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1177e-04 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1524e-04 - accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2943e-04 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1036e-04 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0193e-04 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2985e-04 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 9ms/step - loss: 9.7154e-06 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4523e-04 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1999e-04 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 9ms/step - loss: 3.1840e-05 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.5183e-05 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 9ms/step - loss: 8.0453e-04 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2080e-04 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.0168e-04 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1096e-04 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.4223e-05 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.1958e-05 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0207e-05 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.7005e-04 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3886e-04 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4802e-04 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1414e-05 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.5548e-04 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 9ms/step - loss: 8.9266e-05 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 9ms/step - loss: 3.8446e-04 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2669e-04 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4988e-05 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.5108e-05 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.9604e-06 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.5377e-05 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2308e-05 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 10ms/step - loss: 7.0398e-05 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.1888e-06 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.5223e-05 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.5330e-05 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1458e-06 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.7219e-06 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 11ms/step - loss: 6.5832e-05 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1757e-05 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8901e-04 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0481 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.4232e-05 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0773e-05 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.7461e-05 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.1334e-05 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1682e-05 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 10ms/step - loss: 5.7388e-05 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 9ms/step - loss: 8.2735e-05 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0699e-05 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.6012e-05 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.1381e-05 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9173e-06 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.9311e-05 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1220e-04 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 12ms/step - loss: 7.5761e-04 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.8645e-06 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 15ms/step - loss: 1.0267e-05 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6152e-05 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 13ms/step - loss: 7.7336e-06 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.8692e-05 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 9ms/step - loss: 9.1359e-05 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 9ms/step - loss: 8.9302e-05 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.6921e-06 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9086e-05 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3900e-05 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.4859e-05 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.1784e-05 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 15ms/step - loss: 3.1185e-05 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3560e-06 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.0223e-04 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.0053e-05 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 8ms/step - loss: 7.1218e-05 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8996e-04 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.1955e-06 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.9442e-05 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3478e-06 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.5484e-05 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0091e-04 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0231e-04 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.5597e-06 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 15ms/step - loss: 9.1193e-05 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4692e-05 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2154e-06 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.1212e-05 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.6252e-05 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2040e-05 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9503e-05 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.6038e-04 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.6799e-04 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.5879e-06 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 11ms/step - loss: 8.8467e-05 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 8ms/step - loss: 7.1458e-05 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8875e-04 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.6930e-04 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8312e-06 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.0287e-05 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.7425e-05 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2368e-06 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 12ms/step - loss: 8.2302e-05 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.4071e-04 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.0266e-06 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 9ms/step - loss: 9.6087e-05 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.7638e-04 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.7067e-05 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7270e-05 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.5608e-04 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.6548e-05 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4587e-06 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9246e-05 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.6488e-05 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 7ms/step - loss: 8.6724e-06 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.0438e-05 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3842e-07 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.2672e-04 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.2911e-05 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9210e-05 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 9ms/step - loss: 3.6955e-06 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5839e-05 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4543e-05 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.3446e-07 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2397e-05 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.4075e-07 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.6523e-05 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7074e-04 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2532e-05 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 9ms/step - loss: 9.9838e-07 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.9222e-06 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4587e-06 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.6775e-05 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 8ms/step - loss: 7.4570e-05 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.3213e-07 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2650e-06 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.5465e-06 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7225e-05 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.9470e-05 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.1872e-06 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.1905e-06 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.5408e-04 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.5851e-05 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.6495e-04 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1846e-05 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 1.0000

# %% [markdown]
# Beberapa fungsi untuk chatbot

# %%
def ourText(text):
  newtkns = nltk.word_tokenize(text)
  newtkns = [lm.lemmatize(word) for word in newtkns]
  return newtkns

def wordBag(text, vocab):
  newtkns = ourText(text)
  bagOwords = [0] * len(vocab)
  for w in newtkns:
    for idx, word in enumerate(vocab):
      if word == w:
        bagOwords[idx] = 1
  return num.array(bagOwords)

def Pclass(text, vocab, labels):
  bagOwords = wordBag(text, vocab)
  ourResult = ourNewModel.predict(num.array([bagOwords]))[0]
  newThresh = 0.2
  yp = [[idx, res] for idx, res in enumerate(ourResult) if res > newThresh]

  yp.sort(key=lambda x: x[1], reverse=True)
  newList = []
  for r in yp:
    newList.append(labels[r[0]])
  return newList

def getRes(firstlist, fJson):
  tag = firstlist[0]
  listOfIntents = fJson["ourIntents"]
  for i in listOfIntents:
    if i["tag"] == tag:
      ourResult = random.choice(i["responses"])
      break
  return ourResult

# %% [markdown]
# Kita jalankan chatbot nya

# %%
while True:
    newMessage = input("")
    intents = Pclass(newMessage, newWords, ourClasses)
    ourResult = getRes(intents, ourData)
    print(ourResult)
# Out:
# Hi
# 1/1 [==============================] - 0s 60ms/step
# Hello
# Hi
# 1/1 [==============================] - 0s 17ms/step
# Hi :)
# How old are you
# 1/1 [==============================] - 0s 20ms/step
# I am 2 years old and my birthday was yesterday
# what's your name
# 1/1 [==============================] - 0s 16ms/step
# I have no name yet,You can give me one, and I will appreciate it
# where do you live
# 1/1 [==============================] - 0s 16ms/step
# I have no name yet,You can give me one, and I will appreciate it
# bye
# 1/1 [==============================] - 0s 27ms/step
# Bye
# bye
# 1/1 [==============================] - 0s 17ms/step
# Bye
# bye
# 1/1 [==============================] - 0s 16ms/step
# Bye
# later
# 1/1 [==============================] - 0s 16ms/step
# take care
