# %%
# packages to store and manipulate data
import pandas as pd
import numpy as np

# plotting packages
import matplotlib.pyplot as plt
import seaborn as sns

# model building package
import sklearn

# package to clean text
import re

# %% [markdown]
# Loading data dari Google drive. Data disimpan di variabel bernama df

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('./drive/MyDrive/Colab Notebooks/TopicModelling/climate_tweets.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Melihat 10 baris teratas (mengintip) data dari df

# %%
df.head(10)
# Out:
#                                                tweet
# 0  Global warming report urges governments to act...
# 1  Fighting poverty and global warming in Africa ...
# 2  Carbon offsets: How a Vatican forest failed to...
# 3  Carbon offsets: How a Vatican forest failed to...
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...
# 5  RT @sejorg: RT @JaymiHeimbuch: Ocean Saltiness...
# 6  Global warming evidence all around us|A messag...
# 7  Migratory Birds' New Climate Change Strategy: ...
# 8  Southern Africa: Competing for Limpopo Water: ...
# 9  Global warming to impact wheat, rice productio...

# %% [markdown]
# Membuat kolom baru bernama is_retweet.
# Kolom is_retweet berisi apakah tweet nya mengandung "retweet"

# %%
# make a new column to highlight retweets
df['is_retweet'] = df['tweet'].apply(lambda x: x[:2]=='RT')

# %% [markdown]
# Kita lihat df yang baru setelah penambahan kolom. head(10) untuk mengintip 10 teratas

# %%
df.head(10)
# Out:
#                                                tweet  is_retweet
# 0  Global warming report urges governments to act...       False
# 1  Fighting poverty and global warming in Africa ...       False
# 2  Carbon offsets: How a Vatican forest failed to...       False
# 3  Carbon offsets: How a Vatican forest failed to...       False
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       False
# 5  RT @sejorg: RT @JaymiHeimbuch: Ocean Saltiness...        True
# 6  Global warming evidence all around us|A messag...       False
# 7  Migratory Birds' New Climate Change Strategy: ...       False
# 8  Southern Africa: Competing for Limpopo Water: ...       False
# 9  Global warming to impact wheat, rice productio...       False

# %% [markdown]
# Berapa sih jumlah tweet yang di retweet?

# %%
df['is_retweet'].sum()  # number of retweets
# Out:
# 773

# %% [markdown]
# Berapa sih jumlah retweet yang unik? (ada beberapa tweet yang diretweet lebih dari sekali)

# %%
# number of unique retweets
df.loc[df['is_retweet']].tweet.unique().size
# Out:
# 677

# %% [markdown]
# Memunculkan 10 besar tweet yang paling banyak di retweet

# %%
# 10 most repeated tweets
df.groupby(['tweet']).size().reset_index(name='counts')\
  .sort_values('counts', ascending=False).head(10)
# Out:
#                                                   tweet  counts
# 3131  No matter if you believe in global warming or ...      20
# 4555  Take Action @change: Help Protect Wildlife Hab...      14
# 4027  RT @newtgingrich: Historic snow storm in washi...       9
# 1765       Fight Climate Change From All Fronts: [link]       8
# 1626  Earth's polar ice sheets vulnerable to even mo...       7
# 1941  Global Warming Dent's El Ni'o's Protective Shi...       7
# 1799  Foes of California's global warming law pour m...       6
# 1351  Coalition of the Tired of Waiting: Fighting Cl...       6
# 4271  SCIENCE: Scientists explore the evolution of c...       6
# 1040  Carbon offsets: How a Vatican forest failed to...       6

# %% [markdown]
# Menghitung jumlah retweet setiap tweet dan membuat plotnya.Atau menghitung berapa kali tweet muncul

# %%
# number of times each tweet appears
counts = df.groupby(['tweet']).size()\
           .reset_index(name='counts')\
           .counts

# define bins for histogram
my_bins = np.arange(0,counts.max()+2, 1)-0.5

# plot histogram of tweet counts
plt.figure()
plt.hist(counts, bins = my_bins)
plt.xlabels = np.arange(1,counts.max()+1, 1)
plt.xlabel('copies of each tweet')
plt.ylabel('frequency')
plt.yscale('log', nonposy='clip')
plt.show()

# %% [markdown]
# Membuat fungsi untuk mencari tweet yang mengandung retweet, tweet yang memention orang dan tweet yang mengandung hashtags (#)

# %%
def find_retweeted(tweet):
    '''This function will extract the twitter handles of retweed people'''
    return re.findall('(?<=RT\s)(@[A-Za-z]+[A-Za-z0-9-_]+)', tweet)

def find_mentioned(tweet):
    '''This function will extract the twitter handles of people mentioned in the tweet'''
    return re.findall('(?<!RT\s)(@[A-Za-z]+[A-Za-z0-9-_]+)', tweet)  

def find_hashtags(tweet):
    '''This function will extract hashtags'''
    return re.findall('(#[A-Za-z]+[A-Za-z0-9-_]+)', tweet)

# %% [markdown]
# Membuat 3 kolom baru (retweeted, mentioned, hashtag) yang isi dari kolom tersebut berdasar fungsi diatas

# %%
# make new columns for retweeted usernames, mentioned usernames and hashtags
df['retweeted'] = df.tweet.apply(find_retweeted)
df['mentioned'] = df.tweet.apply(find_mentioned)
df['hashtags'] = df.tweet.apply(find_hashtags)

# %% [markdown]
# Kita intip df yang baru menggunakan head

# %%
df.head(20)
# Out:
#                                                 tweet  is_retweet  \
# 0   Global warming report urges governments to act...       False
# 1   Fighting poverty and global warming in Africa ...       False
# 2   Carbon offsets: How a Vatican forest failed to...       False
# 3   Carbon offsets: How a Vatican forest failed to...       False
# 4   URUGUAY: Tools Needed for Those Most Vulnerabl...       False
# 5   RT @sejorg: RT @JaymiHeimbuch: Ocean Saltiness...        True
# 6   Global warming evidence all around us|A messag...       False
# 7   Migratory Birds' New Climate Change Strategy: ...       False
# 8   Southern Africa: Competing for Limpopo Water: ...       False
# 9   Global warming to impact wheat, rice productio...       False
# 10  How do we solve this global warming thing? [link]       False
# 11  Blog|A preliminary analysis suggests that natu...       False
# 12  Ecotone: #Climate change from a #population pe...       False
# ...

# %% [markdown]
# Fungsi untuk memfilter tweet yang ada hashtag nya saja. Disimpan di variabel bernama "hashtags_list_df"

# %%
# take the rows from the hashtag columns where there are actually hashtags
hashtags_list_df = df.loc[
                       df.hashtags.apply(
                           lambda hashtags_list: hashtags_list !=[]
                       ),['hashtags']]

# %% [markdown]
# Kita intip 10 teratas dari tweet yang mengandung Hashtag

# %%
hashtags_list_df.head(10)
# Out:
#                                              hashtags
# 12                            [#Climate, #population]
# 16                                        [#EarthDay]
# 26                                              [#ac]
# 31                                            [#tcot]
# 36  [#tornadocot, #ocra, #sgp, #gop, #ucot, #tlot,...
# 37                               [#justinbiebersucks]
# 39                                       [#tcot, #p2]
# 48                                 [#IPCC, #teaparty]
# 70                          [#global, #climate, #eco]
# 79                          [#EarthWeek, #Indigenous]

# %% [markdown]
# Kita ingin membuat database yang isinya Hashtag saja. Database tersebut kita simpan di variabel bernama flattened_hashtags_df

# %%
# create dataframe where each use of hashtag gets its own row
flattened_hashtags_df = pd.DataFrame(
    [hashtag for hashtags_list in hashtags_list_df.hashtags
    for hashtag in hashtags_list],
    columns=['hashtag'])

# %% [markdown]
# Kita intip database dari hashtag tersebut (flattened_hashtags_df)

# %%
flattened_hashtags_df.head(20)
# Out:
#                hashtag
# 0             #Climate
# 1          #population
# 2            #EarthDay
# 3                  #ac
# 4                #tcot
# 5          #tornadocot
# 6                #ocra
# 7                 #sgp
# 8                 #gop
# 9                #ucot
# 10               #tlot
# 11                 #p2
# 12              #tycot
# 13  #justinbiebersucks
# 14               #tcot
# 15                 #p2
# 16               #IPCC
# 17           #teaparty
# 18             #global
# 19            #climate

# %% [markdown]
# Karena ada hashtags yang dobel di database nya, kita hitung jumlah database yang unik (nggak double counting)

# %%
# number of unique hashtags
flattened_hashtags_df['hashtag'].unique().size
# Out:
# 477

# %% [markdown]
# Menghitung jumlah hashtag yang muncul dari database hashtag (flattened_hashtag_df) dan menampilkan hashtag paling populer alias diurutkan dari yang paling populer. Hasilnya disimpan divariabel bernama popular_hashtag

# %%
# count of appearances of each hashtag
popular_hashtags = flattened_hashtags_df.groupby('hashtag').size()\
                                        .reset_index(name='counts')\
                                        .sort_values('counts', ascending=False)\
                                        .reset_index(drop=True)

# %% [markdown]
# Kita intip popular_hashtag

# %%
popular_hashtags.head(10)
# Out:
#           hashtag  counts
# 0           #tcot     227
# 1        #climate     202
# 2             #p2     112
# 3          #green      50
# 4  #climatechange      47
# 5       #teaparty      41
# 6         #global      40
# 7            #eco      40
# 8      #SaveTerra      36
# 9    #climategate      33

# %% [markdown]
# Menghitung jumlah Hashtag yang muncul di database (disimpan di variabel flattened_hashtags_df) lalu membuat plot nya

# %%
# number of times each hashtag appears
counts = flattened_hashtags_df.groupby(['hashtag']).size()\
                              .reset_index(name='counts')\
                              .counts

# define bins for histogram                              
my_bins = np.arange(0,counts.max()+2, 5)-0.5

# plot histogram of tweet counts
plt.figure()
plt.hist(counts, bins = my_bins)
plt.xlabels = np.arange(1,counts.max()+1, 1)
plt.xlabel('hashtag number of appearances')
plt.ylabel('frequency')
plt.yscale('log', nonposy='clip')
plt.show()

# %% [markdown]
# Fungsi untuk memFilter hashtags yang muncul lebih dari atau sama dengan 10 kali. Hasilnya disimpan di variabel popular_hashtags_Set

# %%
# take hashtags which appear at least this amount of times
min_appearance = 10
# find popular hashtags - make into python set for efficiency
popular_hashtags_set = set(popular_hashtags[
                           popular_hashtags.counts>=min_appearance
                           ]['hashtag'])

# %% [markdown]
# Menambambah kolom baru bernama popular_hashtag. Kolom "popular_hashtag" tersebut diisi dengan fungsi filtering hashtag yang muncul lebih dari 10 kali

# %%
# make a new column with only the popular hashtags
hashtags_list_df['popular_hashtags'] = hashtags_list_df.hashtags.apply(
            lambda hashtag_list: [hashtag for hashtag in hashtag_list
                                  if hashtag in popular_hashtags_set])

# %% [markdown]
# saya intip hastags_list_df

# %%
hashtags_list_df.head(10)
# Out:
#                                              hashtags  \
# 12                            [#Climate, #population]
# 16                                        [#EarthDay]
# 26                                              [#ac]
# 31                                            [#tcot]
# 36  [#tornadocot, #ocra, #sgp, #gop, #ucot, #tlot,...
# 37                               [#justinbiebersucks]
# 39                                       [#tcot, #p2]
# 48                                 [#IPCC, #teaparty]
# 70                          [#global, #climate, #eco]
# 79                          [#EarthWeek, #Indigenous]
#
#                    popular_hashtags
# 12                       [#Climate]
# 16                      [#EarthDay]
# 26                               []
# 31                          [#tcot]
# 36  [#ocra, #sgp, #gop, #tlot, #p2]
# 37                               []
# 39                     [#tcot, #p2]
# 48               [#IPCC, #teaparty]
# ...

# %% [markdown]
# Drop tweet atau baris yang TIDAK mengandung popular hashtag (muncul lebih dari atau sama dengan 10 kali). Hasilnya disimpan di variabel bernama "popular hashtags_list_df"

# %%
# drop rows without popular hashtag
popular_hashtags_list_df = hashtags_list_df.loc[
            hashtags_list_df.popular_hashtags.apply(lambda hashtag_list: hashtag_list !=[])]

# %% [markdown]
# Kita intip isi dari popular_hashtags_list_df

# %%
popular_hashtags_list_df.head(10)
# Out:
#                                               hashtags  \
# 12                             [#Climate, #population]
# 16                                         [#EarthDay]
# 31                                             [#tcot]
# 36   [#tornadocot, #ocra, #sgp, #gop, #ucot, #tlot,...
# 39                                        [#tcot, #p2]
# 48                                  [#IPCC, #teaparty]
# 70                           [#global, #climate, #eco]
# 137                                   [#EPA, #climate]
# 138                         [#Canadian, #CEOs, #green]
# 140                                         [#climate]
#
#                     popular_hashtags
# 12                        [#Climate]
# 16                       [#EarthDay]
# 31                           [#tcot]
# 36   [#ocra, #sgp, #gop, #tlot, #p2]
# 39                      [#tcot, #p2]
# 48                [#IPCC, #teaparty]
# 70         [#global, #climate, #eco]
# 137                       [#climate]
# ...

# %% [markdown]
# Kita membuat data frame (tabel) menggunakan pandas. kolom nya berisi vektor atau seluruh list hashtag. Barisnya berisi tweet yang mengandung popular hashtag. Lalu diberi index 1 atau 0. 1 jika muncul kata pada kolom yang berisi list seluruh hashtag

# %%
# make new dataframe
hashtag_vector_df = popular_hashtags_list_df.loc[:, ['popular_hashtags']]

for hashtag in popular_hashtags_set:
    # make columns to encode presence of hashtags
    hashtag_vector_df['{}'.format(hashtag)] = hashtag_vector_df.popular_hashtags.apply(
        lambda hashtag_list: int(hashtag in hashtag_list))

# %%
hashtag_vector_df.head(10)
# Out:
#                     popular_hashtags  #cochabamba  #teaparty  #news  \
# 12                        [#Climate]            0          0      0
# 16                       [#EarthDay]            0          0      0
# 31                           [#tcot]            0          0      0
# 36   [#ocra, #sgp, #gop, #tlot, #p2]            0          0      0
# 39                      [#tcot, #p2]            0          0      0
# 48                [#IPCC, #teaparty]            0          1      0
# 70         [#global, #climate, #eco]            0          0      0
# 137                       [#climate]            0          0      0
# 138                         [#green]            0          0      0
# 140                       [#climate]            0          0      0
#
#      #earthday  #snowpocalypse  #environment  #globalwarming  #Green  \
# 12           0               0             0               0       0
# 16           0               0             0               0       0
# ...

# %% [markdown]
# Membuang atau mendrop kolom yang namanya popular_hashtag. Hasilnya disimpan di variabel hashtag_matrix

# %%
hashtag_matrix = hashtag_vector_df.drop('popular_hashtags', axis=1)

# %% [markdown]
# Kita intip hashtag_matrix

# %%
hashtag_matrix.head(10)
# Out:
#      #cochabamba  #teaparty  #news  #earthday  #snowpocalypse  #environment  \
# 12             0          0      0          0               0             0
# 16             0          0      0          0               0             0
# 31             0          0      0          0               0             0
# 36             0          0      0          0               0             0
# 39             0          0      0          0               0             0
# 48             0          1      0          0               0             0
# 70             0          0      0          0               0             0
# 137            0          0      0          0               0             0
# 138            0          0      0          0               0             0
# 140            0          0      0          0               0             0
#
#      #globalwarming  #Green  #SaveTerra  #energy  ...  #IPCC  #fb  #News  \
# ...

# %% [markdown]
# Menghitung dan memplot correlation matrix

# %%
# calculate the correlation matrix
correlations = hashtag_matrix.corr()

# plot the correlation matrix
plt.figure(figsize=(10,10))
sns.heatmap(correlations,
    cmap='RdBu',
    vmin=-1,
    vmax=1,
    square = True,
    cbar_kws={'label':'correlation'})
plt.show()

# %%
import nltk
nltk.download('stopwords')
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def remove_links(tweet):
    '''Takes a string and removes web links from it'''
    tweet = re.sub(r'http\S+', '', tweet) # remove http links
    tweet = re.sub(r'bit.ly/\S+', '', tweet) # rempve bitly links
    tweet = tweet.strip('[link]') # remove [links]
    return tweet

def remove_users(tweet):
    '''Takes a string and removes retweet and @user information'''
    tweet = re.sub('(RT\s@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove retweet
    tweet = re.sub('(@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove tweeted at
    return tweet

# %%
my_stopwords = nltk.corpus.stopwords.words('english')
word_rooter = nltk.stem.snowball.PorterStemmer(ignore_stopwords=False).stem
my_punctuation = '!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~•@'

# cleaning master function
def clean_tweet(tweet, bigrams=False):
    tweet = remove_users(tweet)
    tweet = remove_links(tweet)
    tweet = tweet.lower() # lower case
    tweet = re.sub('['+my_punctuation + ']+', ' ', tweet) # strip punctuation
    tweet = re.sub('\s+', ' ', tweet) #remove double spacing
    tweet = re.sub('([0-9]+)', '', tweet) # remove numbers
    tweet_token_list = [word for word in tweet.split(' ')
                            if word not in my_stopwords] # remove stopwords

    tweet_token_list = [word_rooter(word) if '#' not in word else word
                        for word in tweet_token_list] # apply word rooter
    if bigrams:
        tweet_token_list = tweet_token_list+[tweet_token_list[i]+'_'+tweet_token_list[i+1]
                                            for i in range(len(tweet_token_list)-1)]
    tweet = ' '.join(tweet_token_list)
    return tweet

# %%
df['clean_tweet'] = df.tweet.apply(clean_tweet)

# %%
df.head(10)
# Out:
#                                                tweet  is_retweet  \
# 0  Global warming report urges governments to act...       False
# 1  Fighting poverty and global warming in Africa ...       False
# 2  Carbon offsets: How a Vatican forest failed to...       False
# 3  Carbon offsets: How a Vatican forest failed to...       False
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       False
# 5  RT @sejorg: RT @JaymiHeimbuch: Ocean Saltiness...        True
# 6  Global warming evidence all around us|A messag...       False
# 7  Migratory Birds' New Climate Change Strategy: ...       False
# 8  Southern Africa: Competing for Limpopo Water: ...       False
# 9  Global warming to impact wheat, rice productio...       False
#
#                    retweeted mentioned hashtags  \
# 0                         []        []       []
# 1                         []        []       []
# 2                         []        []       []
# 3                         []        []       []
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=0.9, min_df=25, token_pattern='\w+|\$[\d\.]+|\S+')

# apply transformation
tf = vectorizer.fit_transform(df['clean_tweet']).toarray()

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names_out()

# %%
from sklearn.decomposition import LatentDirichletAllocation

number_of_topics = 10

model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)

# %%
model.fit(tf)
# Out:
# LatentDirichletAllocation(random_state=0)

# %%
def display_topics(model, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return pd.DataFrame(topic_dict)

# %%
no_top_words = 10
display_topics(model, tf_feature_names, no_top_words)
# Out:
#   Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0        climat          1220.2        global           666.5        global
# 1         chang          1184.5          warm           658.1          warm
# 2           via           257.9          snow           160.5     scientist
# 3        scienc           112.9         #tcot           121.6           say
# 4          news            79.5          like            99.0        scienc
# 5           day            77.8      blizzard            90.9         debat
# 6         earth            68.2            dc            86.5           man
# 7         trial            68.1         think            83.3          made
# 8        clinic            68.1           due            80.1          show
# 9        carbon            64.5          make            70.4         water
#
#   Topic 2 weights Topic 3 words Topic 3 weights Topic 4 words Topic 4 weights  \
# ...
