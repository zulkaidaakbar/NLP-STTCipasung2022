# %%
# Install vaderSentiment package for VADER
# !pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 5.0 MB/s
# ...

# %% [markdown]
# Import packages

# %%
# Data processing
import pandas as pd
import numpy as np


# Import VADER sentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Import accuracy_score to check performance
from sklearn.metrics import accuracy_score

# Set a wider colwith
pd.set_option('display.max_colwidth', 1000)

# %% [markdown]
# Load data dan disimpan di variabel bernama review_data

# %%
from google.colab import drive
drive.mount('/content/drive')
review_data = pd.read_csv('./drive/MyDrive/Colab Notebooks/TopicModelling/Reviews_Filter.csv')
review_data.head(10)
# Out:
# Mounted at /content/drive
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 7   8  B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 8   9  B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 9  10  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# ...

# %% [markdown]
# Data tidak saya bersihkan karena akan membuat ambigu. Membuat kolom baru bernama 'scores_VADER' yang isinya adalah compound atau polarity score yang menggambarkan sentiman

# %%
# Get sentiment score for each review
vader_sentiment = SentimentIntensityAnalyzer()
review_data['scores_VADER'] = review_data['Text'].apply(lambda s: vader_sentiment.polarity_scores(s)['compound'])
review_data.head(10)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 7   8  B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 8   9  B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 9  10  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# ...

# %%
review_data.head(20)
# Out:
#     Id   ProductId          UserId                      ProfileName  \
# 0    1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1    2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2    3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3    4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4    5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5    6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6    7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 7    8  B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 8    9  B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 9   10  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
# 10  11  B0001PB9FE  A3HDKO7OW0QNK4                     Canadian Fan
# 11  12  B0009XLVG0  A2725IB4YY9JEB           A Poeng "SparkyGoHome"
# 12  13  B0009XLVG0   A327PCT23YH90                               LT
# ...

# %%
import seaborn as sns #https://www.python-graph-gallery.com/20-basic-histogram-seaborn
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (12, 9)
sns.set()
sns.set_context("talk")

# %%
sns.histplot(review_data['scores_VADER'],  label='Score')

# %% [markdown]
# Filter untuk review yang mengandung kata 'coffee' lalu disimpan di variabel yang bernama coffee

# %%
coffee = review_data[review_data['Text'].str.contains('coffee')]

sns.histplot(coffee['scores_VADER'], label='coffee')

# %%
coffee.head(10)
# Out:
#       Id   ProductId          UserId                ProfileName  \
# 30    31  B003F6UO7K   AFM0O9480F04W                    Sherril
# 55    56  B002GWHC0G  A2EFAW1P3DRXWO                 TJ Fairfax
# 82    83  B003ZFRKGO  A2VOZX7YBT0D6D  Johnnycakes "Johnnycakes"
# 111  112  B0037LW78C  A3VEYLW2KPZNGK                 G. Simmons
# 112  113  B0037LW78C  A2F65U0UDY7TAW                       Aldo
# 153  154  B002HQAXUW  A17ESTP5T7T1PH                   Bumbeda1
# 171  172  B001IUKD76  A2KVCXTQVN18KI    A. Martin "tony_fourbu"
# 173  174  B0081XN2HQ  A3HUV0ZQPXO3V7         Pink Dandy Chatter
# 188  189  B004V6AH34   ATX44LVZL5JFV                      Silvy
# 189  190  B004V6AH34  A3AFVGFX175F9N        Gift Card Recipient
#
#      HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 30                      0                       0      5  1297641600
# 55                      0                       0      5  1349395200
# ...

# %% [markdown]
# Filter review2 yang mengandung kata price. Lalu hasilnya simpan di variabel yang bernama price juga

# %%
price = review_data[review_data['Text'].str.contains('price')]

sns.histplot(price['scores_VADER'],  label='price')

# %%
price.head(20)
# Out:
#       Id   ProductId          UserId                    ProfileName  \
# 4      5  B006K2ZZ7K  A1UQRSCLF8GW1T  Michael D. Bigham "M. Wassir"
# 19    20  B001GVISJM  A3IV7CL2C13K2U                           Greg
# 21    22  B001GVISJM   AZOF9E17RGZH8                 Tammy Anderson
# 27    28  B001GVISJM   AAAS38B98HMIK                   Heather Dube
# 30    31  B003F6UO7K   AFM0O9480F04W                        Sherril
# 31    32  B003F6UO7K  A31OQO709M20Y7        Molly V. Smith "staral"
# 36    37  B001EO5QW8  A1MYS9LFFBIYKM       Abby Chase "gluten free"
# 60    61  B004N5KULM  A1ZR8O62VSU4OK         Lisa J. Szlosek "lisa"
# 68    69  B000E7VI7S  A1KL2LAW08X6UQ                     calmnsense
# 71    72  B001GVISJC  A3BDOAPSF96WGQ                          2tall
# 90    91  B0019CW0HE  A1OGD72Y2Y26CF                       Lisas201
# 94    95  B0019CW0HE  A1DJAAKLPCJRZD                          wendy
# 112  113  B0037LW78C  A2F65U0UDY7TAW                           Aldo
# ...
