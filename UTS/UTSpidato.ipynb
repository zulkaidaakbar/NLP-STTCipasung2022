# %%
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %% [markdown]
# nltk bahasa indonesia-1: pySastrawi

# %%
# !pip install PySastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 210 kB 5.1 MB/s
# ...

# %% [markdown]
# istall nltk bahasa indonesia-2: Sastrawi

# %%
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 209 kB 4.9 MB/s
# ...

# %% [markdown]
# import library2 umum

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# Load data lalu simpat di variable isi_berita

# %%
from google.colab import drive
drive.mount('/content/drive')
f = open('./drive/MyDrive/Colab Notebooks/UTS/Pidato_Jokowi_2022.txt', 'r')
isi_berita = f.read()
print(isi_berita)
# Out:
# Mounted at /content/drive
# Tantangan yang kita hadapi sangat berat. Sangat sulit. Tidak mudah. Semua negara di seluruh dunia sedang menghadapi ujian yang sama. Krisis kesehatan pandemi Covid-19 belum sepenuhnya pulih. Perekonomian dunia juga belum sepenuhnya bangkit. Tiba-tiba meletus perang di Ukraina, sehingga krisis pangan, krisis energi, dan krisis keuangan tidak terhindarkan lagi.
#
# Kita tahu 107 negara terdampak krisis, dan sebagian di antaranya diperkirakan akan jatuh bangkrut. Diperkirakan 553 juta jiwa terancam kemiskinan ekstrem, dan 345 juta jiwa terancam kekurangan pangan dan kelaparan.
#
# Ujian ini tidak mudah bagi dunia dan juga tidak mudah bagi Indonesia. Semua ini harus kita hadapi dengan kehati-hatian, dengan kewaspadaan. Namun, di tengah tantangan yang berat, kita patut bersyukur, Indonesia termasuk negara yang mampu menghadapi krisis global ini.
#
# ...

# %%
f2 = open('./drive/MyDrive/Colab Notebooks/UTS/Pidato_Jokowi_2021.txt', 'r')
isi_berita2 = f2.read()
print(isi_berita2)
# Out:
# Krisis, resesi, dan pandemi itu seperti api. Kalau bisa, kita hindari, tetapi jika hal itu tetap terjadi, banyak hal yang bisa kita pelajari. Api memang membakar, tetapi juga sekaligus menerangi. Kalau terkendali, dia menginspirasi dan memotivasi. Dia menyakitkan, tetapi sekaligus juga menguatkan. Kita ingin pandemi ini menerangi kita untuk mawas diri, memperbaiki diri, dan menguatkan diri, dalam menghadapi tantangan masa depan.
#
# Pandemi itu seperti kawah candradimuka yang menguji, yang mengajarkan, dan sekaligus mengasah. Pandemi memberikan beban yang berat kepada kita, beban yang penuh dengan risiko, dan memaksa kita untuk menghadapi dan mengelolanya. Semua pilar kehidupan kita diuji, semua pilar kekuatan kita diasah. Ketabahan, kesabaran, ketahanan, kebersamaan, kepandaian, dan kecepatan kita, semuanya diuji dan sekaligus diasah.
#
# ...

# %% [markdown]
# Tokenize: potong jadi kata-kata (Token)

# %%
word_tokens = word_tokenize(isi_berita)
print(word_tokens)
# Out:
# ['Tantangan', 'yang', 'kita', 'hadapi', 'sangat', 'berat', '.', 'Sangat', 'sulit', '.', 'Tidak', 'mudah', '.', 'Semua', 'negara', 'di', 'seluruh', 'dunia', 'sedang', 'menghadapi', 'ujian', 'yang', 'sama', '.', 'Krisis', 'kesehatan', 'pandemi', 'Covid-19', 'belum', 'sepenuhnya', 'pulih', '.', 'Perekonomian', 'dunia', 'juga', 'belum', 'sepenuhnya', 'bangkit', '.', 'Tiba-tiba', 'meletus', 'perang', 'di', 'Ukraina', ',', 'sehingga', 'krisis', 'pangan', ',', 'krisis', 'energi', ',', 'dan', 'krisis', 'keuangan', 'tidak', 'terhindarkan', 'lagi', '.', 'Kita', 'tahu', '107', 'negara', 'terdampak', 'krisis', ',', 'dan', 'sebagian', 'di', 'antaranya', 'diperkirakan', 'akan', 'jatuh', 'bangkrut', '.', 'Diperkirakan', '553', 'juta', 'jiwa', 'terancam', 'kemiskinan', 'ekstrem', ',', 'dan', '345', 'juta', 'jiwa', 'terancam', 'kekurangan', 'pangan', 'dan', 'kelaparan', '.', 'Ujian', 'ini', 'tidak', 'mudah', 'bagi', 'dunia', 'dan', 'juga', 'tidak', 'mudah', 'bagi', 'Indonesia', '.', 'Semua', 'ini', '
# ...

# %%
word_tokens2 = word_tokenize(isi_berita2)
print(word_tokens2)
# Out:
# ['Krisis', ',', 'resesi', ',', 'dan', 'pandemi', 'itu', 'seperti', 'api', '.', 'Kalau', 'bisa', ',', 'kita', 'hindari', ',', 'tetapi', 'jika', 'hal', 'itu', 'tetap', 'terjadi', ',', 'banyak', 'hal', 'yang', 'bisa', 'kita', 'pelajari', '.', 'Api', 'memang', 'membakar', ',', 'tetapi', 'juga', 'sekaligus', 'menerangi', '.', 'Kalau', 'terkendali', ',', 'dia', 'menginspirasi', 'dan', 'memotivasi', '.', 'Dia', 'menyakitkan', ',', 'tetapi', 'sekaligus', 'juga', 'menguatkan', '.', 'Kita', 'ingin', 'pandemi', 'ini', 'menerangi', 'kita', 'untuk', 'mawas', 'diri', ',', 'memperbaiki', 'diri', ',', 'dan', 'menguatkan', 'diri', ',', 'dalam', 'menghadapi', 'tantangan', 'masa', 'depan', '.', 'Pandemi', 'itu', 'seperti', 'kawah', 'candradimuka', 'yang', 'menguji', ',', 'yang', 'mengajarkan', ',', 'dan', 'sekaligus', 'mengasah', '.', 'Pandemi', 'memberikan', 'beban', 'yang', 'berat', 'kepada', 'kita', ',', 'beban', 'yang', 'penuh', 'dengan', 'risiko', ',', 'dan', 'memaksa', 'kita', 'untuk', 'menghadap
# ...

# %% [markdown]
# Baris tambahan: Menghilangkan titik, koma, tanda seru, tanda petik. Juga membuat huruf kecil (lowecase)

# %%
word_tokens=[word.lower() for word in word_tokens if word.isalpha()]
word_tokens2=[word.lower() for word in word_tokens2 if word.isalpha()]

# %% [markdown]
# Hilangkan stopwords

# %%
stop_words = set(stopwords.words('indonesian'))
word_tokens_no_stopwords = [w for w in word_tokens if not w in stop_words]
print(word_tokens_no_stopwords)
# Out:
# ['tantangan', 'hadapi', 'berat', 'sulit', 'mudah', 'negara', 'dunia', 'menghadapi', 'ujian', 'krisis', 'kesehatan', 'pandemi', 'sepenuhnya', 'pulih', 'perekonomian', 'dunia', 'sepenuhnya', 'bangkit', 'meletus', 'perang', 'ukraina', 'krisis', 'pangan', 'krisis', 'energi', 'krisis', 'keuangan', 'terhindarkan', 'negara', 'terdampak', 'krisis', 'jatuh', 'bangkrut', 'juta', 'jiwa', 'terancam', 'kemiskinan', 'ekstrem', 'juta', 'jiwa', 'terancam', 'kekurangan', 'pangan', 'kelaparan', 'ujian', 'mudah', 'dunia', 'mudah', 'indonesia', 'hadapi', 'kewaspadaan', 'tantangan', 'berat', 'patut', 'bersyukur', 'indonesia', 'negara', 'menghadapi', 'krisis', 'global', 'negara', 'indonesia', 'negara', 'berhasil', 'mengendalikan', 'pandemi', 'negara', 'vaksinasi', 'dunia', 'juta', 'dosis', 'vaksin', 'suntikkan', 'inflasi', 'berhasil', 'dikendalikan', 'kisaran', 'persen', 'angka', 'inflasi', 'asean', 'persen', 'inflasi', 'maju', 'persen', 'pertengahan', 'apbn', 'surplus', 'triliun', 'pemerintah', 'subsidi'
# ...

# %%
word_tokens_no_stopwords_2 = [w for w in word_tokens2 if not w in stop_words]
print(word_tokens_no_stopwords_2)
# Out:
# ['krisis', 'resesi', 'pandemi', 'api', 'hindari', 'pelajari', 'api', 'membakar', 'menerangi', 'terkendali', 'menginspirasi', 'memotivasi', 'menyakitkan', 'menguatkan', 'pandemi', 'menerangi', 'mawas', 'memperbaiki', 'menguatkan', 'menghadapi', 'tantangan', 'pandemi', 'kawah', 'candradimuka', 'menguji', 'mengajarkan', 'mengasah', 'pandemi', 'beban', 'berat', 'beban', 'penuh', 'risiko', 'memaksa', 'menghadapi', 'mengelolanya', 'pilar', 'kehidupan', 'diuji', 'pilar', 'kekuatan', 'diasah', 'ketabahan', 'kesabaran', 'ketahanan', 'kebersamaan', 'kepandaian', 'kecepatan', 'diuji', 'diasah', 'ujian', 'asahan', 'sisi', 'mata', 'uang', 'terpisahkan', 'beban', 'kesempatan', 'memperbaiki', 'diajarkan', 'tatkala', 'ujian', 'berat', 'asahannya', 'meningkat', 'proses', 'bangsa', 'tahan', 'banting', 'kokoh', 'memenangkan', 'gelanggang', 'pertandingan', 'air', 'perjalanan', 'sejarah', 'bangsa', 'indonesia', 'ujian', 'berat', 'alhamdulillah', 'berhasil', 'melampauinya', 'kemerdekaan', 'republik', 'ind
# ...

# %% [markdown]
# Hitung frequency kata

# %%
freq_kata = nltk.FreqDist(word_tokens_no_stopwords)
print(freq_kata.most_common(20))
# Out:
# [('indonesia', 23), ('negara', 15), ('dunia', 15), ('krisis', 14), ('masyarakat', 12), ('ekonomi', 12), ('pemerintah', 9), ('menghadapi', 7), ('global', 7), ('kekuatan', 7), ('nasional', 7), ('hilirisasi', 7), ('pangan', 6), ('energi', 6), ('persen', 6), ('triliun', 6), ('bangsa', 6), ('sosial', 6), ('negeri', 6), ('meningkatkan', 6)]

# %%
freq_kata2 = nltk.FreqDist(word_tokens_no_stopwords_2)
print(freq_kata2.most_common(20))
# Out:
# [('pandemi', 31), ('indonesia', 26), ('kesehatan', 19), ('pemerintah', 17), ('masyarakat', 14), ('kerja', 13), ('ekonomi', 12), ('negara', 11), ('bangsa', 9), ('menghadapi', 8), ('perekonomian', 8), ('umkm', 8), ('meningkatkan', 8), ('membangun', 7), ('nasional', 7), ('utama', 7), ('ujian', 6), ('sosial', 6), ('dunia', 6), ('pengembangan', 6)]

# %% [markdown]
# Plotting

# %%
import matplotlib.pyplot as plt
freq_kata.plot(20)
plt.show()
freq_kata2.plot(20)
plt.show()
